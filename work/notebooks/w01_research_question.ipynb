# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/faheem-danish/internship-starter-1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
## My Lane

#I selected Lane 2: Refresh / Content Opportunity Scoring.

#I chose this lane because it focuses on identifying webpages that should be reviewed first for content updates or SEO improvements. Instead of checking every page manually, a ranked recommendation system can help prioritize pages with the greatest opportunity. This lane matches the starter dataset and allows me to build a practical decision-support system for content optimization.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
## The Question
"""
Decision: Which webpages should be reviewed first for content refresh or SEO improvement?

Who acts:
SEO specialists or content managers who decide which pages should be updated.

Action:
Review and improve the highest-ranked pages by updating content, titles, metadata, or structure.

Cost of wrong recommendation:
If low-priority pages are selected, time and resources are wasted. If important pages are ignored, the website may lose traffic opportunities.

Machine learning can help by finding patterns in website performance data and ranking pages for review.
"""
# Out:
# '\nDecision: Which webpages should be reviewed first for content refresh or SEO improvement?\n\nWho acts:\nSEO specialists or content managers who decide which pages should be updated.\n\nAction:\nReview and improve the highest-ranked pages by updating content, titles, metadata, or structure.\n\nCost of wrong recommendation:\nIf low-priority pages are selected, time and resources are wasted. If important pages are ignored, the website may lose traffic opportunities.\n\nMachine learning can help by finding patterns in website performance data and ranking pages for review.\n'

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
## Quick Look at the Data
"""
The dataset contains 30,000 webpage records with SEO performance metrics.
The average CTR is 0.511, the average search position is 16.34, and the average impressions over 90 days are 5200.37.

These numbers show that pages have different levels of performance, making it useful to build a system that ranks pages for possible content refresh opportunities.
"""
# Out:
# '\nThe dataset contains 30,000 webpage records with SEO performance metrics. \nThe average CTR is 0.511, the average search position is 16.34, and the average impressions over 90 days are 5200.37.\n\nThese numbers show that pages have different levels of performance, making it useful to build a system that ranks pages for possible content refresh opportunities.\n'

# %%
# !git clone https://github.com/faheem-danish/internship-starter-1.git
# Out:
# fatal: destination path 'internship-starter-1' already exists and is not an empty directory.

# %%
import os

print(os.listdir('/content'))
# Out:
# ['.config', 'internship-starter-1', 'sample_data']

# %%
import os

for root, dirs, files in os.walk('/content/internship-starter-1'):
    for file in files:
        if "content_refresh" in file:
            print(os.path.join(root,file))
# Out:
# /content/internship-starter-1/data/raw/content_refresh_anonymized.csv

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
# ## Careful Words
#
# This project provides decision-support based on observed data.
#
# It can identify patterns in SEO performance and rank webpages that may need review.
#
# It cannot prove that updating a page will increase traffic or predict Google's ranking algorithm.
#
# The recommendations are directional and should be combined with human judgment before making final decisions.

# %%
import pandas as pd

df = pd.read_csv("/content/internship-starter-1/data/raw/content_refresh_anonymized.csv")

print("Number of pages:", len(df))
print("Average CTR:", round(df["ctr"].mean(), 3))
print("Average Position:", round(df["avg_position"].mean(), 2))
print("Average Impressions:", round(df["impressions_90d"].mean(), 2))
# Out:
# Number of pages: 30000
# Average CTR: 0.511
# Average Position: 16.34
# Average Impressions: 5200.37

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
